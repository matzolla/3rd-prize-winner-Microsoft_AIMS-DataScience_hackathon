# %% [markdown]
# ## About the Problem
#
# Granular information on economic well being is extremely useful for governments and policy makers. But household surveys that capture this kind of information are expensive and conducted infrequently in many African countries. For this competition we will attempt to create a workaround for this lack of data by building a model able to predict a measure of wealth as measured in household surveys using readily available inputs.
#
# Using data from 18 different countries collected at different times, you must correctly predict the cluster level estimated wealth measures found from surveys in 7 different countries not covered in the training data. A successful model could be useful for filling in the gaps between the more expensive surveys.

# %% [markdown]
# ## Importing Useful packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Loading The Dataset
#
# We load the train,test and sample submission file

# %%
#loading our train and sample submission file:
train=pd.read_csv('Train.csv')

# %%
test=pd.read_csv('Test.csv')

# %%
submit=pd.read_csv('SampleSubmission.csv')

# %%
#An overview of the train set using train.head()
train.head()
# Out:
#             ID     country  year  ... dist_to_capital  dist_to_shoreline    Target
# 0  ID_AAIethGy    Ethiopia  2016  ...      278.788451         769.338378  0.132783
# 1  ID_AAYiaCeL    Ethiopia  2005  ...      200.986978         337.135243  0.004898
# 2  ID_AAdurmKj  Mozambique  2009  ...      642.594208         169.913773  0.097320
# 3  ID_AAgNHles      Malawi  2015  ...      365.349451         613.591610  0.304107
# 4  ID_AAishfND      Guinea  2012  ...      222.867189         192.926363  0.605328
#
# [5 rows x 19 columns]

# %%
test.describe()
# Out:
#               year  ghsl_water_surface  ...  dist_to_capital  dist_to_shoreline
# count  7194.000000         7194.000000  ...      7194.000000        7194.000000
# mean   2010.899778            0.023317  ...       332.979023         686.113119
# std       3.651409            0.087915  ...       341.906808         368.546747
# min    1998.000000            0.000000  ...         0.437825           0.898246
# 25%    2010.000000            0.000000  ...       101.060708         409.104775
# 50%    2011.000000            0.000000  ...       241.468141         759.849023
# 75%    2014.000000            0.000000  ...       415.621994         954.987511
# max    2016.000000            0.991100  ...      1908.105037        1748.559242
#
# [8 rows x 15 columns]

# %% [markdown]
# ## Exploratory Data Analysis
#
# * I tried to check whether there exist missing values in the dataset, and the result was **negatif** (no missing values, a good news).
# * checking also for correlation between the independent\independent variables and independent\target variable
# reveals some strong negatif correlation between the predictors (example ghsl_not_built_up and nighttime_light). We also some independent variables revealing strong positive correlation  with the target variables (ghsl_pop_density, landcover_urban_fraction, nighttime_lights)
# * Cluster with large urban proportion,high nighttime light and relatively large population density turn to have a high wealth index.

# %%
#checking for missing values, identifying the categorical and numerical variables.
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21454 entries, 0 to 21453
# Data columns (total 19 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ID                                       21454 non-null  object
#  1   country                                  21454 non-null  object
#  2   year                                     21454 non-null  int64
#  3   urban_or_rural                           21454 non-null  object
#  4   ghsl_water_surface                       21454 non-null  float64
#  5   ghsl_built_pre_1975                      21454 non-null  float64
#  6   ghsl_built_1975_to_1990                  21454 non-null  float64
#  7   ghsl_built_1990_to_2000                  21454 non-null  float64
#  8   ghsl_built_2000_to_2014                  21454 non-null  float64
#  9   ghsl_not_built_up                        21454 non-null  float64
#  10  ghsl_pop_density                         21454 non-null  float64
#  11  landcover_crops_fraction                 21454 non-null  float64
#  12  landcover_urban_fraction                 21454 non-null  float64
#  13  landcover_water_permanent_10km_fraction  21454 non-null  float64
#  14  landcover_water_seasonal_10km_fraction   21454 non-null  float64
#  15  nighttime_lights                         21454 non-null  float64
#  16  dist_to_capital                          21454 non-null  float64
#  17  dist_to_shoreline                        21454 non-null  float64
#  18  Target                                   21454 non-null  float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 3.1+ MB

# %% [markdown]
# We have variables like 'urban_or_rural','country' and 'ID' which are categorical variables and the remaining ones are numeric. We also have no missing information on the train set.

# %% [markdown]
# ### Correlation matrix between independent variables

# %%
sns.set_theme(style="white")
d = pd.DataFrame(data=train,
                 columns=train.columns)

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# e.g regions with large proportion of land not built  up, will turn to have a small nighttime light therefore accounting for the strong negatif correlation between this two independent variables.

# %%
train.plot(x='nighttime_lights', y='Target', kind='scatter', alpha=0.2)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# Plotting the relationship nighttime_lights and the wealth index(Target), seems to present a strong positive correlation althought the values are almost sqwashed to zero. Normally the greater the nighttime light, the greater the economic activity therefore a greater wealth index.

# %%
#investigating the countries in train and test set
train.country.value_counts()
# Out:
# Nigeria                     2695
# Kenya                       2626
# Tanzania                    2450
# Malawi                      1957
# Ethiopia                    1721
# Ghana                       1419
# Mali                        1295
# Cameroon                    1041
# Rwanda                       984
# Senegal                      903
# Mozambique                   879
# Lesotho                      794
# Sierra Leone                 785
# Guinea                       593
# Cote d'Ivoire                481
# Togo                         330
# Swaziland                    270
# Central African Republic     231
# Name: country, dtype: int64

# %%
#same in the test
test.country.value_counts()
# Out:
# Uganda                          1584
# Zimbabwe                        1189
# Zambia                          1038
# Burkina Faso                     997
# Angola                           855
# Democratic Republic of Congo     785
# Benin                            746
# Name: country, dtype: int64

# %% [markdown]
# * Important finding: The countries in the test set are completely different from the countries in the train set. This kind of scenario will probably affect the test data as far as **generalization** is concern (the model will be unable to generalize well on unseen data).To over come this problem i build a customized train_test_split, which splits my train data , based on the feauture name **country**, i.e the model is trained on a given set of countries and validates on a country with which it hasn't been trained with. By so doing i search for the model with the smallest mean_square_error (the model that generalizes well on unseen data) and use it to do my prediction on the test set.

# %% [markdown]
# ### Feature Engineering and data Preprocessing

# %% [markdown]
# * Important finding: trying to categorize continuous variable really improve the model. Despite the fact that i couldn't create indicator function for certain abnormalities(patterns that i think to be abnormal), it is possible to quantify some continuous variable based on ranges of values.
# * Example i created a feature that characterize the population density interms of **small size, medium size, big and very big size** it gives more meaning to the actual values found in the ghsl_pop_density column.
#
# * I did thesame for the distance to capital, which is also a good indicator of the wealth index.

# %%
# the function below takes 
"""input____:
name of data set:data
the column you want to categorize: a
the name of the newly created feature: b
output____:
a newly created column with categorical values, interms of size and base on the percentile of the feature
you want to caategorize"""
def group(data,a,b):
  data[b]='none'
  for i,j in enumerate(data[a]):
    if j>= np.min(data[a]) and j < np.percentile(data[a],25):
      data.loc[i,b]='small'
    elif j>= np.percentile(data[a],25) and j< np.percentile(data[a],50):
      data.loc[i,b]='medium'
    elif j>=np.percentile(data[a],50) and j< np.percentile(data[a],75):
      data.loc[i,b]='big'
    elif j>= np.percentile(data[a],75):
      data.loc[i,b]='very_big'
  return data

# %%
#creating categorical variable for the feature dist_to_capital
test=group(test,'dist_to_capital','dist')
train=group(train,'dist_to_capital','dist')

# %%
#creating categorical variable for the population density
test=group(test,'ghsl_pop_density','pop_size')
train=group(train,'ghsl_pop_density','pop_size')

# %% [markdown]
# The two features created below was based on the splitting of my train data, using the customized function built to do so. The minimum error obtain after training my model with each splits (one split containing 17 countries and the last split containing the last country, i did so manually for all the 18 countries in the train set), reveals that, the country **Guinea** has the smallest mean square error, predicting the wealth index using this model will probably have a good generalization perfomance.

# %%
#the mean square error for country Kenya is 0.016986217308540524
#the mean square error for country Nigeria is 0.04404187886936057
#the mean square error for country Tanzania is 0.013086158167263358
#the mean square error for country Malawi is 0.01059467702900494
#the mean square error for country Ethiopia is 0.00926243755596883
#the mean square error for country Ghana is 0.019099523614234493
#the mean square error for country Mali is 0.010061246293276543
#the mean square error for country Cameroon is 0.009041880250884263
#the mean square error for country Rwanda is 0.00968488508539336
#the mean square error for country Senegal is 0.02888667326733214
#the mean square error for country Mozambique is 0.015774485558534893
#the mean square error for country Lesotho is 0.015923862512533117
#the mean square error for country Sierra Leone is 0.011198435721676813
#the mean square error for country Guinea is 0.007688508743601999
#the mean square error for country Cote d'Ivoire is 0.03506951538358788
#the mean square error for country Togo is 0.018535950450297024
#the mean square error for country Swaziland is 0.05061226689827493
#the mean square error for country Central African Republic is 0.0365024889587078

# %%
#I Created this feature based on the distribution of the country Guinea, i wanted the dataset to have 
# a kind of similar distribution with that of guinea the reason been that if Guinea reveals the smallest
#mean square error, then if my train data looks similar to it, the overall mean square error will also decrease
# and it actually decreased.
train["capital_n"]=0
test["capital_n"]=0
def create_features(data):
    for i,j in enumerate(data["dist_to_capital"]):
        if j<1.038623: # this value is the smallest distance to capital of Guinea
            data.loc[i,"capital_n"]=1
    return data

# %% [markdown]
# Looking at the **Corpernicus** global landcover with water layers,(and also from some research papers) i realised that regions with permanent land water and temporal land water turn to have good yiels of crops production(that will surely lead to a good wealth index). But in an attempt to bring out a relationship between **landcover_crop_fraction** and **landcover_water_permanent/seasonal**, the error increased tremendously. So i decided to limit my self on creating **seasonality** indicator for the landcover water seasonal feature. Clusters with landcover water seasonal=0, are probably in the dry season, and regions with seasonal water different from 0 are surely in the rainy seasons. The later have more access to water and will probably have good crop yields.
#
# Again this feature improved my position on the leaderboard

# %%
#Creating seasonality feature
train["seasons"]=0
test["seasons"]=0
def seasonality(data):
    for i,j in enumerate(data["landcover_water_seasonal_10km_fraction"]):
        if j==0:
          data.loc[i,"seasons"]=1 #dry seasons areas
    return data

# %% [markdown]
# *  Next, i looked around checking the population global settlement, built-up lands before 1975 to 2014 (ghsl_pre_1975 to ghsl_2000_to_2014). Normaly the proportion of land not built up is equal to $1-total ~~proportion~~of~~land~~built$. But again there were some abnormalities in the data

# %%
# summing all the proportion of lands (built and not built), should give us one normally
#train['check_proportion']=train['ghsl_built_pre_1975']+train['ghsl_built_1975_to_1990']+train['ghsl_built_1990_to_2000']+train['ghsl_built_2000_to_2014']+train['ghsl_not_built_up']
#len(train[train.check_proportion!=1])

# %% [markdown]
# We have exactly **12975** clusters presenting that abnormality, again i created an indicator variable for that, and it really reduced the error on the leaderboard

# %%
#Checking for proportionality in distribution of land built layers
train["abnormal_built_proportion"]=0
test["abnormal_built_proportion"]=0
def abnormal_built(data):
  for i,j in enumerate(data):
    if data.loc[i,'ghsl_not_built_up']+data.loc[i,'ghsl_built_pre_1975']+data.loc[i,'ghsl_built_2000_to_2014']+data.loc[i,'ghsl_built_1990_to_2000']+data.loc[i,'ghsl_built_1975_to_1990']!=1:
      data.loc[i,'abnormal_built_proportion']=1
  return data

# %%
#create a variable for the year 2012 and 1999 according to the distribution of Guinea
train["year_n"]=0
test["year_n"]=0
def year(data):
    for i,j in enumerate(data["year"]):
        if j==2012 or j==1999: # this are the two different years for which informations for the clusters in Guinea were collected
            data.loc[i,"year_n"]=1
    return data

# %% [markdown]
# Again, using the corpenicus global landcover layers we realize whenever there is global settlement, the ratio of previous/impervious land increases with time (pervious lands could be urban areas and impervious could be rural urban), meaning that the proportion urban areas could probably increase as time goes on.
#
# * With this finding i classified the lands based on their **built_year** if a land is built below year 2000, the land is probably impervious (at this period) and from year 2000 and above the land becomes more and more pervious
#
# This finding slightly reduce the error in the leaderboard.

# %%
train['built_year']=0
test['built_year']=0
def building_year(data):
  for i,j in enumerate(data["year"]):
    if j<2000:
      data.loc[i,'built_year']=1
  return data

# %% [markdown]
# * The nighttime_light: I started by checking if there exist some clusters where there could be nighttime light intensity, without a **human settlement(population density)** or again human settlement without any nighttime light. The reason throught this is because, if there is human settlement in a given region, there should surely be a little amount of nighttime economic activities, and also regions with no human settlements are likely not to have economic nighttime economic activities(they could be forest,mountains...)

# %%
#checking existence of regions of nighttime light with no human settlement and vice-versa
len(train[((train.ghsl_pop_density ==0)&(train.nighttime_lights!=0))|((train.ghsl_pop_density !=0)&(train.nighttime_lights==0))])
# Out:
# 8893

# %% [markdown]
# * There exist around **8893** clusters, fufilling the condition above, so we start by creating an empty column named **abnormal_light** and fill them with zeros, then the clusters(index) which fullfill the condition, we replace the zero by one. This newly created feature turned to reduce the error in the public leader board.

# %%
#creating the function for abnormal nighttime light intensity
train["abnormal_light"]=0
test['abnormal_light']=0
def abnormal_light(data):
    for i,j in enumerate(data[((data.ghsl_pop_density ==0)&(data.nighttime_lights!=0))|((data.ghsl_pop_density !=0)&(data.nighttime_lights==0))]):
        data.loc[i,"abnormal_light"]=1
    return data

# %%
#feauture for guinea distribution
tr=create_features(train)
test=create_features(test)
# feature for the year of collection of 
#information for Guinea
tr=year(tr)
test=year(test)
# Fitting the abnormal light feature
tr=abnormal_light(tr)
test=abnormal_light(test)
##features about the abnormally built up lands
tr=abnormal_built(tr)
test=abnormal_built(test)
#features about pervious/impervious lands
tr=building_year(tr)
test=building_year(test)
#features about water seasonality
tr=seasonality(tr)
test=seasonality(test)

# %%
"""The function below splits my train data, into 17 countries for training
and 1 country for validation.
input___: The name of the country with which the split will be done
output___: 4 variables representing our split interms
of the portion of training and validation(like the train_test_split)"""
def split(a):
    data=tr[tr.country!=a]
    x_train=data.drop("Target",axis=1)
    y_train=data["Target"]
    data_2=tr[tr.country==a]
    x_val=data_2.drop("Target",axis=1)
    y_val=data_2["Target"]
    return x_train,x_val,y_train,y_val

# %%
a="Guinea"
x_train,x_val,y_train,y_val=split(a)

# %% [markdown]
# Important: after splitting our train data, we decided to drop the column country, because it was of know used after.

# %% [markdown]
# ### Data Preprocessing
# * The numerical variables were simply normalized using min max scaling
# * The urban_or_rural variable was label encode (since it only contains 2 categories)
#
# * Our newly created features (from the group function) were one_hot encoded
#
# all this preprocessing was done using the preprocessed function below.

# %%
# creating our label encoder object
le=LabelEncoder()

# %%
#we define a simple function to preprocess our data
def preprocess(data):
    data=data.drop(["ID",'country'],axis=1)
    categ=['dist','pop_size']
    #trying with one hot encoding of the country variable
    #data=pd.get_dummies(data,prefix_sep="_",columns=["country"])
    data["urban_or_rural"]=le.fit_transform(data["urban_or_rural"])
    #data["light_size"]=le.fit_transform(data["light_size"])
    data = pd.get_dummies(data, prefix_sep="_", columns=categ)
    scaler=MinMaxScaler(feature_range=(0,1))# we normalize the variables into values between (0 and 1)
    data=scaler.fit_transform(data)
    return data

# %%
#preprocessing our data as well as the test data (test_prp)
x_train=preprocess(x_train)
x_val=preprocess(x_val)
test_prp=preprocess(test)

# %% [markdown]
# # Now we can build our model
#
# * Catboost reveals to perform very well
# * I tried neural network but didn't perform better than catboost

# %%
# !pip install catboost

# %%
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error

# %%
#for max_depth in [3, 5, 8, 10, 14, 18]:
#    model = CatBoostRegressor(max_depth=max_depth)
    # Again, you van use a better method to evaluate the model here...
#    model.fit(x_train, y_train)
#    print(max_depth, mean_squared_error(y_val, model.predict(x_val)))

# %% [markdown]
# No parameter tunning was done. This is because the train set distribution is different from the test set distribution. As a result the cross validation score obtain in the train data will be different on the test data(leader board score), so i decided to rely on my cross validation based on countries, i followed my instinct :)

# %%
#model3
model_3=CatBoostRegressor()
model_3.fit(x_train,y_train)
model_3.score(x_val,y_val)
# Out:
# Learning rate set to 0.067026
# 0:	learn: 0.1864543	total: 56.4ms	remaining: 56.3s
# 1:	learn: 0.1792022	total: 64.3ms	remaining: 32.1s
# 2:	learn: 0.1722518	total: 72.4ms	remaining: 24s
# 3:	learn: 0.1659234	total: 80.6ms	remaining: 20.1s
# 4:	learn: 0.1603716	total: 88.7ms	remaining: 17.7s
# 5:	learn: 0.1550011	total: 96.9ms	remaining: 16s
# 6:	learn: 0.1503351	total: 105ms	remaining: 14.9s
# 7:	learn: 0.1458284	total: 113ms	remaining: 14s
# 8:	learn: 0.1418551	total: 121ms	remaining: 13.3s
# 9:	learn: 0.1380545	total: 129ms	remaining: 12.7s
# 10:	learn: 0.1347733	total: 137ms	remaining: 12.3s
# 11:	learn: 0.1316667	total: 145ms	remaining: 11.9s
# 12:	learn: 0.1289429	total: 153ms	remaining: 11.6s
# 13:	learn: 0.1264927	total: 161ms	remaining: 11.3s
# 14:	learn: 0.1242664	total: 169ms	remaining: 11.1s
# 15:	learn: 0.1221072	total: 177ms	remaining: 10.9s
# 16:	learn: 0.1203312	total: 190ms	remaining: 11s
# 17:	learn: 0.1186208	total: 198ms	remaining: 10.8s
# 18:	learn: 0.1170488	total: 206ms	remaining: 10.7s
# 19:	learn: 0.1155760	total: 214ms	remaining: 10.5s
# 20:	learn: 0.1143079	total: 222ms	remaining: 10.3s
# 21:	learn: 0.1130879	total: 230ms	remaining: 10.2s
# 22:	learn: 0.1120491	total: 238ms	remaining: 10.1s
# 23:	learn: 0.1110822	total: 246ms	remaining: 9.99s
# 24:	learn: 0.1101723	total: 254ms	remaining: 9.9s
# 25:	learn: 0.1093545	total: 261ms	remaining: 9.79s
# 26:	learn: 0.1087196	total: 272ms	remaining: 9.8s
# 27:	learn: 0.1080907	total: 280ms	remaining: 9.71s
# 28:	learn: 0.1075168	total: 288ms	remaining: 9.64s
# 29:	learn: 0.1069575	total: 296ms	remaining: 9.57s
# 30:	learn: 0.1063899	total: 304ms	remaining: 9.49s
# 31:	learn: 0.1059509	total: 312ms	remaining: 9.43s
# 32:	learn: 0.1054963	total: 320ms	remaining: 9.37s
# 33:	learn: 0.1050389	total: 328ms	remaining: 9.3s
# 34:	learn: 0.1046481	total: 336ms	remaining: 9.26s
# 35:	learn: 0.1042537	total: 343ms	remaining: 9.2s
# 36:	learn: 0.1039898	total: 351ms	remaining: 9.15s
# 37:	learn: 0.1037364	total: 359ms	remaining: 9.1s
# 38:	learn: 0.1033955	total: 368ms	remaining: 9.06s
# 39:	learn: 0.1031576	total: 375ms	remaining: 9s
# 40:	learn: 0.1028540	total: 383ms	remaining: 8.97s
# 41:	learn: 0.1025719	total: 395ms	remaining: 9.01s
# 42:	learn: 0.1023625	total: 403ms	remaining: 8.97s
# 43:	learn: 0.1021124	total: 411ms	remaining: 8.93s
# 44:	learn: 0.1019061	total: 419ms	remaining: 8.89s
# 45:	learn: 0.1016463	total: 426ms	remaining: 8.84s
# 46:	learn: 0.1014675	total: 434ms	remaining: 8.8s
# 47:	learn: 0.1012596	total: 442ms	remaining: 8.76s
# 48:	learn: 0.1011020	total: 450ms	remaining: 8.72s
# 49:	learn: 0.1009537	total: 457ms	remaining: 8.69s
# 50:	learn: 0.1008354	total: 465ms	remaining: 8.65s
# 51:	learn: 0.1007284	total: 472ms	remaining: 8.61s
# 52:	learn: 0.1005640	total: 480ms	remaining: 8.58s
# 53:	learn: 0.1004485	total: 487ms	remaining: 8.54s
# 54:	learn: 0.1002836	total: 498ms	remaining: 8.56s
# 55:	learn: 0.1001779	total: 506ms	remaining: 8.53s
# 56:	learn: 0.1000242	total: 515ms	remaining: 8.53s
# 57:	learn: 0.0998474	total: 523ms	remaining: 8.49s
# 58:	learn: 0.0996852	total: 531ms	remaining: 8.47s
# 59:	learn: 0.0995769	total: 539ms	remaining: 8.44s
# 60:	learn: 0.0994728	total: 547ms	remaining: 8.41s
# 61:	learn: 0.0993576	total: 556ms	remaining: 8.41s
# 62:	learn: 0.0992887	total: 564ms	remaining: 8.38s
# 63:	learn: 0.0992195	total: 571ms	remaining: 8.35s
# 64:	learn: 0.0990958	total: 582ms	remaining: 8.37s
# 65:	learn: 0.0988732	total: 590ms	remaining: 8.36s
# 66:	learn: 0.0987610	total: 598ms	remaining: 8.33s
# 67:	learn: 0.0986689	total: 606ms	remaining: 8.3s
# 68:	learn: 0.0985280	total: 614ms	remaining: 8.28s
# 69:	learn: 0.0983992	total: 622ms	remaining: 8.26s
# 70:	learn: 0.0983383	total: 629ms	remaining: 8.23s
# 71:	learn: 0.0982322	total: 637ms	remaining: 8.21s
# 72:	learn: 0.0981335	total: 645ms	remaining: 8.19s
# 73:	learn: 0.0980136	total: 652ms	remaining: 8.16s
# 74:	learn: 0.0979532	total: 660ms	remaining: 8.14s
# 75:	learn: 0.0978933	total: 667ms	remaining: 8.11s
# 76:	learn: 0.0977944	total: 676ms	remaining: 8.1s
# 77:	learn: 0.0976662	total: 684ms	remaining: 8.09s
# 78:	learn: 0.0975920	total: 692ms	remaining: 8.06s
# 79:	learn: 0.0974543	total: 700ms	remaining: 8.05s
# 80:	learn: 0.0973836	total: 707ms	remaining: 8.02s
# 81:	learn: 0.0972677	total: 715ms	remaining: 8s
# 82:	learn: 0.0971983	total: 723ms	remaining: 7.99s
# 83:	learn: 0.0971145	total: 733ms	remaining: 7.99s
# 84:	learn: 0.0970510	total: 745ms	remaining: 8.02s
# 85:	learn: 0.0970083	total: 753ms	remaining: 8s
# 86:	learn: 0.0969310	total: 761ms	remaining: 7.99s
# 87:	learn: 0.0968477	total: 769ms	remaining: 7.97s
# 88:	learn: 0.0967748	total: 781ms	remaining: 7.99s
# 89:	learn: 0.0967077	total: 790ms	remaining: 7.98s
# 90:	learn: 0.0966242	total: 797ms	remaining: 7.96s
# 91:	learn: 0.0965498	total: 806ms	remaining: 7.95s
# 92:	learn: 0.0964818	total: 814ms	remaining: 7.94s
# 93:	learn: 0.0964323	total: 823ms	remaining: 7.93s
# 94:	learn: 0.0963785	total: 832ms	remaining: 7.93s
# 95:	learn: 0.0963385	total: 845ms	remaining: 7.96s
# 96:	learn: 0.0962634	total: 856ms	remaining: 7.97s
# 97:	learn: 0.0961631	total: 867ms	remaining: 7.98s
# 98:	learn: 0.0961063	total: 875ms	remaining: 7.96s
# 99:	learn: 0.0959731	total: 883ms	remaining: 7.95s
# 100:	learn: 0.0959010	total: 891ms	remaining: 7.93s
# 101:	learn: 0.0958218	total: 900ms	remaining: 7.92s
# 102:	learn: 0.0957323	total: 908ms	remaining: 7.91s
# 103:	learn: 0.0956556	total: 918ms	remaining: 7.91s
# 104:	learn: 0.0955993	total: 926ms	remaining: 7.89s
# 105:	learn: 0.0955427	total: 934ms	remaining: 7.87s
# 106:	learn: 0.0954965	total: 941ms	remaining: 7.85s
# 107:	learn: 0.0954673	total: 949ms	remaining: 7.83s
# 108:	learn: 0.0953747	total: 965ms	remaining: 7.89s
# 109:	learn: 0.0953305	total: 975ms	remaining: 7.88s
# 110:	learn: 0.0952597	total: 984ms	remaining: 7.88s
# 111:	learn: 0.0952305	total: 991ms	remaining: 7.86s
# 112:	learn: 0.0951801	total: 999ms	remaining: 7.84s
# 113:	learn: 0.0951204	total: 1.01s	remaining: 7.83s
# 114:	learn: 0.0950538	total: 1.01s	remaining: 7.81s
# 115:	learn: 0.0950221	total: 1.02s	remaining: 7.79s
# 116:	learn: 0.0949378	total: 1.03s	remaining: 7.78s
# 117:	learn: 0.0949012	total: 1.04s	remaining: 7.76s
# 118:	learn: 0.0948412	total: 1.04s	remaining: 7.74s
# 119:	learn: 0.0947881	total: 1.05s	remaining: 7.72s
# 120:	learn: 0.0947465	total: 1.06s	remaining: 7.7s
# 121:	learn: 0.0947176	total: 1.07s	remaining: 7.68s
# 122:	learn: 0.0946092	total: 1.08s	remaining: 7.72s
# 123:	learn: 0.0945486	total: 1.09s	remaining: 7.71s
# 124:	learn: 0.0944762	total: 1.1s	remaining: 7.7s
# 125:	learn: 0.0943861	total: 1.11s	remaining: 7.69s
# 126:	learn: 0.0942765	total: 1.12s	remaining: 7.68s
# 127:	learn: 0.0942466	total: 1.12s	remaining: 7.66s
# 128:	learn: 0.0941807	total: 1.14s	remaining: 7.66s
# 129:	learn: 0.0941191	total: 1.14s	remaining: 7.65s
# 130:	learn: 0.0940226	total: 1.15s	remaining: 7.64s
# 131:	learn: 0.0939752	total: 1.16s	remaining: 7.62s
# 132:	learn: 0.0938912	total: 1.17s	remaining: 7.61s
# 133:	learn: 0.0938223	total: 1.18s	remaining: 7.63s
# 134:	learn: 0.0937797	total: 1.2s	remaining: 7.67s
# 135:	learn: 0.0936918	total: 1.21s	remaining: 7.66s
# 136:	learn: 0.0936644	total: 1.21s	remaining: 7.64s
# 137:	learn: 0.0936010	total: 1.22s	remaining: 7.62s
# 138:	learn: 0.0935613	total: 1.23s	remaining: 7.61s
# 139:	learn: 0.0935162	total: 1.24s	remaining: 7.59s
# 140:	learn: 0.0934789	total: 1.24s	remaining: 7.57s
# 141:	learn: 0.0934255	total: 1.25s	remaining: 7.56s
# 142:	learn: 0.0933701	total: 1.26s	remaining: 7.54s
# 143:	learn: 0.0933106	total: 1.27s	remaining: 7.56s
# 144:	learn: 0.0932480	total: 1.28s	remaining: 7.54s
# 145:	learn: 0.0932087	total: 1.29s	remaining: 7.53s
# 146:	learn: 0.0931507	total: 1.29s	remaining: 7.51s
# 147:	learn: 0.0930976	total: 1.3s	remaining: 7.5s
# 148:	learn: 0.0930375	total: 1.31s	remaining: 7.49s
# 149:	learn: 0.0929935	total: 1.32s	remaining: 7.48s
# 150:	learn: 0.0929562	total: 1.33s	remaining: 7.46s
# 151:	learn: 0.0929173	total: 1.33s	remaining: 7.45s
# 152:	learn: 0.0928572	total: 1.34s	remaining: 7.44s
# 153:	learn: 0.0928142	total: 1.35s	remaining: 7.42s
# 154:	learn: 0.0927686	total: 1.36s	remaining: 7.41s
# 155:	learn: 0.0927258	total: 1.37s	remaining: 7.42s
# 156:	learn: 0.0926618	total: 1.38s	remaining: 7.42s
# 157:	learn: 0.0926282	total: 1.39s	remaining: 7.4s
# 158:	learn: 0.0925706	total: 1.4s	remaining: 7.39s
# 159:	learn: 0.0925106	total: 1.41s	remaining: 7.38s
# 160:	learn: 0.0924212	total: 1.41s	remaining: 7.37s
# 161:	learn: 0.0923768	total: 1.42s	remaining: 7.35s
# 162:	learn: 0.0923456	total: 1.43s	remaining: 7.34s
# 163:	learn: 0.0922922	total: 1.44s	remaining: 7.32s
# 164:	learn: 0.0922569	total: 1.45s	remaining: 7.31s
# 165:	learn: 0.0922001	total: 1.46s	remaining: 7.32s
# 166:	learn: 0.0921587	total: 1.47s	remaining: 7.31s
# 167:	learn: 0.0921216	total: 1.47s	remaining: 7.29s
# 168:	learn: 0.0920716	total: 1.48s	remaining: 7.28s
# 169:	learn: 0.0920210	total: 1.49s	remaining: 7.27s
# 170:	learn: 0.0919593	total: 1.5s	remaining: 7.25s
# 171:	learn: 0.0919231	total: 1.5s	remaining: 7.24s
# 172:	learn: 0.0918553	total: 1.51s	remaining: 7.23s
# 173:	learn: 0.0918068	total: 1.52s	remaining: 7.21s
# 174:	learn: 0.0917455	total: 1.53s	remaining: 7.2s
# 175:	learn: 0.0916997	total: 1.53s	remaining: 7.18s
# 176:	learn: 0.0916409	total: 1.54s	remaining: 7.17s
# 177:	learn: 0.0915960	total: 1.55s	remaining: 7.16s
# 178:	learn: 0.0915315	total: 1.56s	remaining: 7.14s
# 179:	learn: 0.0914849	total: 1.56s	remaining: 7.13s
# 180:	learn: 0.0914532	total: 1.58s	remaining: 7.13s
# 181:	learn: 0.0914004	total: 1.58s	remaining: 7.13s
# 182:	learn: 0.0913631	total: 1.59s	remaining: 7.11s
# 183:	learn: 0.0913256	total: 1.6s	remaining: 7.11s
# 184:	learn: 0.0912519	total: 1.61s	remaining: 7.1s
# 185:	learn: 0.0912194	total: 1.62s	remaining: 7.09s
# 186:	learn: 0.0911690	total: 1.63s	remaining: 7.08s
# 187:	learn: 0.0911333	total: 1.64s	remaining: 7.07s
# 188:	learn: 0.0910974	total: 1.64s	remaining: 7.05s
# 189:	learn: 0.0910493	total: 1.65s	remaining: 7.04s
# 190:	learn: 0.0909830	total: 1.66s	remaining: 7.03s
# 191:	learn: 0.0909245	total: 1.67s	remaining: 7.02s
# 192:	learn: 0.0908814	total: 1.68s	remaining: 7.01s
# 193:	learn: 0.0908329	total: 1.68s	remaining: 7s
# 194:	learn: 0.0908042	total: 1.69s	remaining: 6.99s
# 195:	learn: 0.0907652	total: 1.7s	remaining: 6.97s
# 196:	learn: 0.0907133	total: 1.71s	remaining: 6.96s
# 197:	learn: 0.0906704	total: 1.72s	remaining: 6.96s
# 198:	learn: 0.0906380	total: 1.73s	remaining: 6.94s
# 199:	learn: 0.0906066	total: 1.73s	remaining: 6.93s
# 200:	learn: 0.0905515	total: 1.74s	remaining: 6.92s
# 201:	learn: 0.0905018	total: 1.75s	remaining: 6.91s
# 202:	learn: 0.0904728	total: 1.76s	remaining: 6.9s
# 203:	learn: 0.0904465	total: 1.76s	remaining: 6.88s
# 204:	learn: 0.0904079	total: 1.77s	remaining: 6.88s
# 205:	learn: 0.0903489	total: 1.79s	remaining: 6.88s
# 206:	learn: 0.0903222	total: 1.79s	remaining: 6.88s
# 207:	learn: 0.0902700	total: 1.8s	remaining: 6.87s
# 208:	learn: 0.0902218	total: 1.81s	remaining: 6.86s
# 209:	learn: 0.0901538	total: 1.82s	remaining: 6.85s
# 210:	learn: 0.0901203	total: 1.83s	remaining: 6.83s
# 211:	learn: 0.0900636	total: 1.83s	remaining: 6.82s
# 212:	learn: 0.0900275	total: 1.84s	remaining: 6.81s
# 213:	learn: 0.0900105	total: 1.85s	remaining: 6.8s
# 214:	learn: 0.0899707	total: 1.86s	remaining: 6.79s
# 215:	learn: 0.0899418	total: 1.87s	remaining: 6.77s
# 216:	learn: 0.0899065	total: 1.87s	remaining: 6.76s
# 217:	learn: 0.0898828	total: 1.88s	remaining: 6.75s
# 218:	learn: 0.0898444	total: 1.89s	remaining: 6.74s
# 219:	learn: 0.0897998	total: 1.9s	remaining: 6.73s
# 220:	learn: 0.0897525	total: 1.91s	remaining: 6.72s
# 221:	learn: 0.0897024	total: 1.91s	remaining: 6.71s
# 222:	learn: 0.0896581	total: 1.92s	remaining: 6.7s
# 223:	learn: 0.0896035	total: 1.94s	remaining: 6.7s
# 224:	learn: 0.0895553	total: 1.95s	remaining: 6.71s
# 225:	learn: 0.0895143	total: 1.95s	remaining: 6.69s
# 226:	learn: 0.0894675	total: 1.96s	remaining: 6.68s
# 227:	learn: 0.0894185	total: 1.97s	remaining: 6.68s
# 228:	learn: 0.0893898	total: 1.98s	remaining: 6.68s
# 229:	learn: 0.0893548	total: 1.99s	remaining: 6.67s
# 230:	learn: 0.0893213	total: 2s	remaining: 6.65s
# 231:	learn: 0.0892682	total: 2.01s	remaining: 6.64s
# 232:	learn: 0.0892108	total: 2.01s	remaining: 6.63s
# 233:	learn: 0.0891663	total: 2.02s	remaining: 6.62s
# 234:	learn: 0.0891240	total: 2.03s	remaining: 6.61s
# 235:	learn: 0.0891040	total: 2.04s	remaining: 6.59s
# 236:	learn: 0.0890827	total: 2.04s	remaining: 6.58s
# 237:	learn: 0.0890272	total: 2.05s	remaining: 6.57s
# 238:	learn: 0.0889864	total: 2.06s	remaining: 6.56s
# 239:	learn: 0.0889383	total: 2.07s	remaining: 6.55s
# 240:	learn: 0.0889010	total: 2.08s	remaining: 6.54s
# 241:	learn: 0.0888787	total: 2.08s	remaining: 6.53s
# 242:	learn: 0.0888458	total: 2.09s	remaining: 6.52s
# 243:	learn: 0.0888106	total: 2.1s	remaining: 6.51s
# 244:	learn: 0.0887789	total: 2.11s	remaining: 6.5s
# 245:	learn: 0.0887439	total: 2.12s	remaining: 6.48s
# 246:	learn: 0.0886983	total: 2.12s	remaining: 6.47s
# 247:	learn: 0.0886502	total: 2.13s	remaining: 6.46s
# 248:	learn: 0.0885926	total: 2.14s	remaining: 6.45s
# 249:	learn: 0.0885611	total: 2.15s	remaining: 6.44s
# 250:	learn: 0.0885218	total: 2.15s	remaining: 6.43s
# 251:	learn: 0.0885009	total: 2.16s	remaining: 6.42s
# 252:	learn: 0.0884656	total: 2.18s	remaining: 6.43s
# 253:	learn: 0.0884454	total: 2.19s	remaining: 6.42s
# 254:	learn: 0.0884080	total: 2.19s	remaining: 6.41s
# 255:	learn: 0.0883736	total: 2.2s	remaining: 6.4s
# 256:	learn: 0.0883187	total: 2.21s	remaining: 6.39s
# 257:	learn: 0.0882902	total: 2.22s	remaining: 6.38s
# 258:	learn: 0.0882306	total: 2.23s	remaining: 6.37s
# 259:	learn: 0.0881864	total: 2.23s	remaining: 6.36s
# 260:	learn: 0.0881409	total: 2.24s	remaining: 6.34s
# 261:	learn: 0.0881023	total: 2.25s	remaining: 6.34s
# 262:	learn: 0.0880863	total: 2.26s	remaining: 6.33s
# 263:	learn: 0.0880582	total: 2.27s	remaining: 6.32s
# 264:	learn: 0.0880319	total: 2.27s	remaining: 6.3s
# 265:	learn: 0.0880131	total: 2.28s	remaining: 6.29s
# 266:	learn: 0.0879802	total: 2.29s	remaining: 6.28s
# 267:	learn: 0.0879565	total: 2.3s	remaining: 6.28s
# 268:	learn: 0.0879109	total: 2.31s	remaining: 6.27s
# 269:	learn: 0.0878661	total: 2.31s	remaining: 6.26s
# 270:	learn: 0.0878457	total: 2.32s	remaining: 6.24s
# 271:	learn: 0.0878214	total: 2.33s	remaining: 6.23s
# 272:	learn: 0.0877801	total: 2.34s	remaining: 6.22s
# 273:	learn: 0.0877519	total: 2.34s	remaining: 6.21s
# 274:	learn: 0.0877326	total: 2.35s	remaining: 6.2s
# 275:	learn: 0.0876925	total: 2.36s	remaining: 6.19s
# 276:	learn: 0.0876701	total: 2.37s	remaining: 6.18s
# 277:	learn: 0.0876378	total: 2.38s	remaining: 6.18s
# 278:	learn: 0.0876226	total: 2.39s	remaining: 6.17s
# 279:	learn: 0.0875760	total: 2.4s	remaining: 6.16s
# 280:	learn: 0.0875427	total: 2.4s	remaining: 6.15s
# 281:	learn: 0.0875226	total: 2.41s	remaining: 6.14s
# 282:	learn: 0.0874849	total: 2.42s	remaining: 6.13s
# 283:	learn: 0.0874600	total: 2.42s	remaining: 6.11s
# 284:	learn: 0.0874388	total: 2.43s	remaining: 6.1s
# 285:	learn: 0.0873959	total: 2.44s	remaining: 6.09s
# 286:	learn: 0.0873768	total: 2.45s	remaining: 6.08s
# 287:	learn: 0.0873447	total: 2.46s	remaining: 6.07s
# 288:	learn: 0.0873307	total: 2.46s	remaining: 6.06s
# 289:	learn: 0.0872987	total: 2.47s	remaining: 6.05s
# 290:	learn: 0.0872681	total: 2.48s	remaining: 6.05s
# 291:	learn: 0.0872370	total: 2.49s	remaining: 6.04s
# 292:	learn: 0.0872167	total: 2.5s	remaining: 6.03s
# 293:	learn: 0.0871804	total: 2.5s	remaining: 6.02s
# 294:	learn: 0.0871529	total: 2.51s	remaining: 6.01s
# 295:	learn: 0.0871390	total: 2.52s	remaining: 6s
# 296:	learn: 0.0871001	total: 2.53s	remaining: 5.99s
# 297:	learn: 0.0870809	total: 2.54s	remaining: 5.98s
# 298:	learn: 0.0870433	total: 2.54s	remaining: 5.97s
# 299:	learn: 0.0870079	total: 2.55s	remaining: 5.96s
# 300:	learn: 0.0869811	total: 2.56s	remaining: 5.95s
# 301:	learn: 0.0869670	total: 2.57s	remaining: 5.93s
# 302:	learn: 0.0869300	total: 2.58s	remaining: 5.93s
# 303:	learn: 0.0868977	total: 2.59s	remaining: 5.93s
# 304:	learn: 0.0868660	total: 2.6s	remaining: 5.92s
# 305:	learn: 0.0868285	total: 2.6s	remaining: 5.91s
# 306:	learn: 0.0868055	total: 2.62s	remaining: 5.91s
# 307:	learn: 0.0867787	total: 2.62s	remaining: 5.9s
# 308:	learn: 0.0867409	total: 2.63s	remaining: 5.89s
# 309:	learn: 0.0867147	total: 2.64s	remaining: 5.88s
# 310:	learn: 0.0866867	total: 2.65s	remaining: 5.87s
# 311:	learn: 0.0866443	total: 2.66s	remaining: 5.86s
# 312:	learn: 0.0866114	total: 2.67s	remaining: 5.85s
# 313:	learn: 0.0865765	total: 2.67s	remaining: 5.84s
# 314:	learn: 0.0865381	total: 2.68s	remaining: 5.83s
# 315:	learn: 0.0865050	total: 2.69s	remaining: 5.82s
# 316:	learn: 0.0864882	total: 2.7s	remaining: 5.81s
# 317:	learn: 0.0864624	total: 2.7s	remaining: 5.8s
# 318:	learn: 0.0864323	total: 2.71s	remaining: 5.79s
# 319:	learn: 0.0863911	total: 2.72s	remaining: 5.78s
# 320:	learn: 0.0863714	total: 2.73s	remaining: 5.77s
# 321:	learn: 0.0863479	total: 2.73s	remaining: 5.76s
# 322:	learn: 0.0863308	total: 2.74s	remaining: 5.75s
# 323:	learn: 0.0863139	total: 2.75s	remaining: 5.74s
# 324:	learn: 0.0862717	total: 2.76s	remaining: 5.73s
# 325:	learn: 0.0862533	total: 2.77s	remaining: 5.72s
# 326:	learn: 0.0862143	total: 2.78s	remaining: 5.71s
# 327:	learn: 0.0861872	total: 2.79s	remaining: 5.71s
# 328:	learn: 0.0861439	total: 2.79s	remaining: 5.7s
# 329:	learn: 0.0861156	total: 2.8s	remaining: 5.69s
# 330:	learn: 0.0860826	total: 2.81s	remaining: 5.68s
# 331:	learn: 0.0860453	total: 2.83s	remaining: 5.69s
# 332:	learn: 0.0860298	total: 2.83s	remaining: 5.68s
# 333:	learn: 0.0860051	total: 2.84s	remaining: 5.67s
# 334:	learn: 0.0859760	total: 2.85s	remaining: 5.66s
# 335:	learn: 0.0859326	total: 2.86s	remaining: 5.65s
# 336:	learn: 0.0859031	total: 2.87s	remaining: 5.64s
# 337:	learn: 0.0858725	total: 2.88s	remaining: 5.64s
# 338:	learn: 0.0858489	total: 2.89s	remaining: 5.63s
# 339:	learn: 0.0858057	total: 2.89s	remaining: 5.62s
# 340:	learn: 0.0857682	total: 2.91s	remaining: 5.62s
# 341:	learn: 0.0857332	total: 2.92s	remaining: 5.62s
# 342:	learn: 0.0857102	total: 2.93s	remaining: 5.61s
# 343:	learn: 0.0856846	total: 2.94s	remaining: 5.6s
# 344:	learn: 0.0856679	total: 2.94s	remaining: 5.59s
# 345:	learn: 0.0856437	total: 2.95s	remaining: 5.58s
# 346:	learn: 0.0856072	total: 2.96s	remaining: 5.57s
# 347:	learn: 0.0855708	total: 2.96s	remaining: 5.56s
# 348:	learn: 0.0855373	total: 2.98s	remaining: 5.55s
# 349:	learn: 0.0854984	total: 2.99s	remaining: 5.55s
# 350:	learn: 0.0854807	total: 2.99s	remaining: 5.54s
# 351:	learn: 0.0854529	total: 3s	remaining: 5.53s
# 352:	learn: 0.0854279	total: 3.01s	remaining: 5.51s
# 353:	learn: 0.0853949	total: 3.02s	remaining: 5.5s
# 354:	learn: 0.0853707	total: 3.02s	remaining: 5.49s
# 355:	learn: 0.0853466	total: 3.03s	remaining: 5.48s
# 356:	learn: 0.0853378	total: 3.04s	remaining: 5.47s
# 357:	learn: 0.0853182	total: 3.05s	remaining: 5.46s
# 358:	learn: 0.0852865	total: 3.05s	remaining: 5.45s
# 359:	learn: 0.0852621	total: 3.06s	remaining: 5.44s
# 360:	learn: 0.0852350	total: 3.07s	remaining: 5.43s
# 361:	learn: 0.0852031	total: 3.08s	remaining: 5.42s
# 362:	learn: 0.0851835	total: 3.08s	remaining: 5.41s
# 363:	learn: 0.0851573	total: 3.09s	remaining: 5.4s
# 364:	learn: 0.0851424	total: 3.1s	remaining: 5.39s
# 365:	learn: 0.0851275	total: 3.1s	remaining: 5.38s
# 366:	learn: 0.0850949	total: 3.11s	remaining: 5.37s
# 367:	learn: 0.0850679	total: 3.12s	remaining: 5.36s
# 368:	learn: 0.0850530	total: 3.13s	remaining: 5.35s
# 369:	learn: 0.0850348	total: 3.13s	remaining: 5.34s
# 370:	learn: 0.0850025	total: 3.14s	remaining: 5.33s
# 371:	learn: 0.0849804	total: 3.15s	remaining: 5.32s
# 372:	learn: 0.0849542	total: 3.16s	remaining: 5.31s
# 373:	learn: 0.0849338	total: 3.17s	remaining: 5.3s
# 374:	learn: 0.0849138	total: 3.18s	remaining: 5.29s
# 375:	learn: 0.0848904	total: 3.18s	remaining: 5.29s
# 376:	learn: 0.0848686	total: 3.19s	remaining: 5.28s
# 377:	learn: 0.0848412	total: 3.2s	remaining: 5.27s
# 378:	learn: 0.0848200	total: 3.21s	remaining: 5.26s
# 379:	learn: 0.0847891	total: 3.21s	remaining: 5.25s
# 380:	learn: 0.0847648	total: 3.22s	remaining: 5.24s
# 381:	learn: 0.0847371	total: 3.23s	remaining: 5.23s
# 382:	learn: 0.0847267	total: 3.24s	remaining: 5.22s
# 383:	learn: 0.0847130	total: 3.25s	remaining: 5.21s
# 384:	learn: 0.0846873	total: 3.25s	remaining: 5.2s
# 385:	learn: 0.0846594	total: 3.26s	remaining: 5.19s
# 386:	learn: 0.0846372	total: 3.27s	remaining: 5.18s
# 387:	learn: 0.0846098	total: 3.28s	remaining: 5.17s
# 388:	learn: 0.0845968	total: 3.29s	remaining: 5.16s
# 389:	learn: 0.0845642	total: 3.3s	remaining: 5.16s
# 390:	learn: 0.0845411	total: 3.3s	remaining: 5.15s
# 391:	learn: 0.0845196	total: 3.31s	remaining: 5.14s
# 392:	learn: 0.0844900	total: 3.32s	remaining: 5.13s
# 393:	learn: 0.0844661	total: 3.33s	remaining: 5.12s
# 394:	learn: 0.0844464	total: 3.33s	remaining: 5.11s
# 395:	learn: 0.0844169	total: 3.34s	remaining: 5.1s
# 396:	learn: 0.0843991	total: 3.35s	remaining: 5.09s
# 397:	learn: 0.0843750	total: 3.36s	remaining: 5.08s
# 398:	learn: 0.0843577	total: 3.37s	remaining: 5.07s
# 399:	learn: 0.0843299	total: 3.38s	remaining: 5.07s
# 400:	learn: 0.0843139	total: 3.39s	remaining: 5.06s
# 401:	learn: 0.0842896	total: 3.4s	remaining: 5.05s
# 402:	learn: 0.0842653	total: 3.4s	remaining: 5.04s
# 403:	learn: 0.0842395	total: 3.41s	remaining: 5.04s
# 404:	learn: 0.0842016	total: 3.42s	remaining: 5.03s
# 405:	learn: 0.0841864	total: 3.43s	remaining: 5.02s
# 406:	learn: 0.0841640	total: 3.44s	remaining: 5.01s
# 407:	learn: 0.0841510	total: 3.44s	remaining: 5s
# 408:	learn: 0.0841216	total: 3.46s	remaining: 4.99s
# 409:	learn: 0.0841086	total: 3.46s	remaining: 4.98s
# 410:	learn: 0.0840917	total: 3.47s	remaining: 4.97s
# 411:	learn: 0.0840767	total: 3.48s	remaining: 4.96s
# 412:	learn: 0.0840601	total: 3.49s	remaining: 4.96s
# 413:	learn: 0.0840399	total: 3.49s	remaining: 4.95s
# 414:	learn: 0.0840209	total: 3.5s	remaining: 4.94s
# 415:	learn: 0.0839951	total: 3.51s	remaining: 4.93s
# 416:	learn: 0.0839670	total: 3.52s	remaining: 4.92s
# 417:	learn: 0.0839300	total: 3.53s	remaining: 4.91s
# 418:	learn: 0.0839018	total: 3.54s	remaining: 4.91s
# 419:	learn: 0.0838839	total: 3.55s	remaining: 4.9s
# 420:	learn: 0.0838710	total: 3.55s	remaining: 4.89s
# 421:	learn: 0.0838433	total: 3.56s	remaining: 4.88s
# 422:	learn: 0.0838299	total: 3.57s	remaining: 4.87s
# 423:	learn: 0.0838082	total: 3.58s	remaining: 4.87s
# 424:	learn: 0.0837903	total: 3.59s	remaining: 4.86s
# 425:	learn: 0.0837640	total: 3.6s	remaining: 4.85s
# 426:	learn: 0.0837396	total: 3.6s	remaining: 4.84s
# 427:	learn: 0.0837235	total: 3.61s	remaining: 4.83s
# 428:	learn: 0.0836957	total: 3.62s	remaining: 4.82s
# 429:	learn: 0.0836701	total: 3.63s	remaining: 4.81s
# 430:	learn: 0.0836377	total: 3.64s	remaining: 4.8s
# 431:	learn: 0.0836135	total: 3.65s	remaining: 4.79s
# 432:	learn: 0.0835905	total: 3.65s	remaining: 4.78s
# 433:	learn: 0.0835615	total: 3.66s	remaining: 4.77s
# 434:	learn: 0.0835274	total: 3.67s	remaining: 4.76s
# 435:	learn: 0.0834932	total: 3.68s	remaining: 4.76s
# 436:	learn: 0.0834731	total: 3.69s	remaining: 4.75s
# 437:	learn: 0.0834560	total: 3.69s	remaining: 4.74s
# 438:	learn: 0.0834303	total: 3.7s	remaining: 4.73s
# 439:	learn: 0.0834133	total: 3.71s	remaining: 4.72s
# 440:	learn: 0.0833768	total: 3.72s	remaining: 4.71s
# 441:	learn: 0.0833591	total: 3.73s	remaining: 4.7s
# 442:	learn: 0.0833400	total: 3.73s	remaining: 4.69s
# 443:	learn: 0.0833295	total: 3.74s	remaining: 4.68s
# 444:	learn: 0.0833132	total: 3.75s	remaining: 4.67s
# 445:	learn: 0.0832783	total: 3.75s	remaining: 4.67s
# 446:	learn: 0.0832595	total: 3.76s	remaining: 4.66s
# 447:	learn: 0.0832479	total: 3.78s	remaining: 4.66s
# 448:	learn: 0.0832338	total: 3.79s	remaining: 4.65s
# 449:	learn: 0.0832118	total: 3.79s	remaining: 4.64s
# 450:	learn: 0.0831828	total: 3.8s	remaining: 4.63s
# 451:	learn: 0.0831701	total: 3.81s	remaining: 4.62s
# 452:	learn: 0.0831495	total: 3.82s	remaining: 4.61s
# 453:	learn: 0.0831214	total: 3.83s	remaining: 4.6s
# 454:	learn: 0.0831102	total: 3.83s	remaining: 4.59s
# 455:	learn: 0.0830816	total: 3.84s	remaining: 4.58s
# 456:	learn: 0.0830560	total: 3.85s	remaining: 4.58s
# 457:	learn: 0.0830305	total: 3.86s	remaining: 4.57s
# 458:	learn: 0.0830092	total: 3.88s	remaining: 4.57s
# 459:	learn: 0.0829837	total: 3.89s	remaining: 4.56s
# 460:	learn: 0.0829715	total: 3.89s	remaining: 4.55s
# 461:	learn: 0.0829512	total: 3.9s	remaining: 4.54s
# 462:	learn: 0.0829284	total: 3.91s	remaining: 4.54s
# 463:	learn: 0.0829141	total: 3.92s	remaining: 4.53s
# 464:	learn: 0.0828890	total: 3.93s	remaining: 4.52s
# 465:	learn: 0.0828610	total: 3.93s	remaining: 4.51s
# 466:	learn: 0.0828363	total: 3.94s	remaining: 4.5s
# 467:	learn: 0.0828070	total: 3.95s	remaining: 4.49s
# 468:	learn: 0.0827842	total: 3.96s	remaining: 4.48s
# 469:	learn: 0.0827649	total: 3.96s	remaining: 4.47s
# 470:	learn: 0.0827398	total: 3.97s	remaining: 4.46s
# 471:	learn: 0.0827314	total: 3.99s	remaining: 4.46s
# 472:	learn: 0.0827141	total: 3.99s	remaining: 4.45s
# 473:	learn: 0.0827020	total: 4s	remaining: 4.44s
# 474:	learn: 0.0826776	total: 4.01s	remaining: 4.43s
# 475:	learn: 0.0826550	total: 4.02s	remaining: 4.42s
# 476:	learn: 0.0826156	total: 4.03s	remaining: 4.42s
# 477:	learn: 0.0826024	total: 4.04s	remaining: 4.41s
# 478:	learn: 0.0825877	total: 4.04s	remaining: 4.4s
# 479:	learn: 0.0825649	total: 4.05s	remaining: 4.39s
# 480:	learn: 0.0825216	total: 4.06s	remaining: 4.38s
# 481:	learn: 0.0824955	total: 4.07s	remaining: 4.37s
# 482:	learn: 0.0824797	total: 4.07s	remaining: 4.36s
# 483:	learn: 0.0824513	total: 4.08s	remaining: 4.35s
# 484:	learn: 0.0824313	total: 4.09s	remaining: 4.34s
# 485:	learn: 0.0824097	total: 4.1s	remaining: 4.33s
# 486:	learn: 0.0824004	total: 4.1s	remaining: 4.32s
# 487:	learn: 0.0823822	total: 4.11s	remaining: 4.31s
# 488:	learn: 0.0823698	total: 4.12s	remaining: 4.3s
# 489:	learn: 0.0823537	total: 4.13s	remaining: 4.29s
# 490:	learn: 0.0823355	total: 4.13s	remaining: 4.29s
# 491:	learn: 0.0823164	total: 4.14s	remaining: 4.28s
# 492:	learn: 0.0823058	total: 4.15s	remaining: 4.26s
# 493:	learn: 0.0822896	total: 4.16s	remaining: 4.26s
# 494:	learn: 0.0822704	total: 4.16s	remaining: 4.25s
# 495:	learn: 0.0822465	total: 4.17s	remaining: 4.24s
# 496:	learn: 0.0822213	total: 4.18s	remaining: 4.23s
# 497:	learn: 0.0821880	total: 4.19s	remaining: 4.22s
# 498:	learn: 0.0821771	total: 4.2s	remaining: 4.21s
# 499:	learn: 0.0821545	total: 4.2s	remaining: 4.2s
# 500:	learn: 0.0821322	total: 4.21s	remaining: 4.2s
# 501:	learn: 0.0821038	total: 4.22s	remaining: 4.19s
# 502:	learn: 0.0820925	total: 4.23s	remaining: 4.18s
# 503:	learn: 0.0820678	total: 4.24s	remaining: 4.17s
# 504:	learn: 0.0820559	total: 4.24s	remaining: 4.16s
# 505:	learn: 0.0820309	total: 4.25s	remaining: 4.15s
# 506:	learn: 0.0819974	total: 4.26s	remaining: 4.14s
# 507:	learn: 0.0819830	total: 4.27s	remaining: 4.13s
# 508:	learn: 0.0819574	total: 4.27s	remaining: 4.12s
# 509:	learn: 0.0819483	total: 4.28s	remaining: 4.11s
# 510:	learn: 0.0819277	total: 4.29s	remaining: 4.1s
# 511:	learn: 0.0819082	total: 4.3s	remaining: 4.09s
# 512:	learn: 0.0818876	total: 4.3s	remaining: 4.09s
# 513:	learn: 0.0818626	total: 4.31s	remaining: 4.08s
# 514:	learn: 0.0818348	total: 4.32s	remaining: 4.07s
# 515:	learn: 0.0818154	total: 4.33s	remaining: 4.06s
# 516:	learn: 0.0818056	total: 4.34s	remaining: 4.05s
# 517:	learn: 0.0817836	total: 4.34s	remaining: 4.04s
# 518:	learn: 0.0817609	total: 4.35s	remaining: 4.03s
# 519:	learn: 0.0817514	total: 4.36s	remaining: 4.02s
# 520:	learn: 0.0817413	total: 4.37s	remaining: 4.01s
# 521:	learn: 0.0817184	total: 4.38s	remaining: 4.01s
# 522:	learn: 0.0816971	total: 4.39s	remaining: 4s
# 523:	learn: 0.0816845	total: 4.4s	remaining: 3.99s
# 524:	learn: 0.0816721	total: 4.4s	remaining: 3.98s
# 525:	learn: 0.0816555	total: 4.41s	remaining: 3.98s
# 526:	learn: 0.0816350	total: 4.42s	remaining: 3.97s
# 527:	learn: 0.0816024	total: 4.43s	remaining: 3.96s
# 528:	learn: 0.0815773	total: 4.44s	remaining: 3.96s
# 529:	learn: 0.0815625	total: 4.45s	remaining: 3.95s
# 530:	learn: 0.0815484	total: 4.46s	remaining: 3.94s
# 531:	learn: 0.0815374	total: 4.46s	remaining: 3.93s
# 532:	learn: 0.0815190	total: 4.47s	remaining: 3.92s
# 533:	learn: 0.0815036	total: 4.48s	remaining: 3.91s
# 534:	learn: 0.0814867	total: 4.49s	remaining: 3.9s
# 535:	learn: 0.0814567	total: 4.5s	remaining: 3.89s
# 536:	learn: 0.0814439	total: 4.5s	remaining: 3.88s
# 537:	learn: 0.0814268	total: 4.51s	remaining: 3.88s
# 538:	learn: 0.0814140	total: 4.52s	remaining: 3.87s
# 539:	learn: 0.0813920	total: 4.53s	remaining: 3.86s
# 540:	learn: 0.0813583	total: 4.54s	remaining: 3.85s
# 541:	learn: 0.0813397	total: 4.55s	remaining: 3.84s
# 542:	learn: 0.0813170	total: 4.55s	remaining: 3.83s
# 543:	learn: 0.0812986	total: 4.56s	remaining: 3.83s
# 544:	learn: 0.0812692	total: 4.57s	remaining: 3.82s
# 545:	learn: 0.0812517	total: 4.58s	remaining: 3.81s
# 546:	learn: 0.0812363	total: 4.59s	remaining: 3.8s
# 547:	learn: 0.0812090	total: 4.6s	remaining: 3.8s
# 548:	learn: 0.0811994	total: 4.61s	remaining: 3.79s
# 549:	learn: 0.0811879	total: 4.62s	remaining: 3.78s
# 550:	learn: 0.0811639	total: 4.63s	remaining: 3.77s
# 551:	learn: 0.0811492	total: 4.63s	remaining: 3.76s
# 552:	learn: 0.0811323	total: 4.64s	remaining: 3.75s
# 553:	learn: 0.0811079	total: 4.65s	remaining: 3.74s
# 554:	learn: 0.0810877	total: 4.66s	remaining: 3.73s
# 555:	learn: 0.0810762	total: 4.67s	remaining: 3.73s
# 556:	learn: 0.0810663	total: 4.68s	remaining: 3.72s
# 557:	learn: 0.0810523	total: 4.69s	remaining: 3.71s
# 558:	learn: 0.0810411	total: 4.7s	remaining: 3.7s
# 559:	learn: 0.0810230	total: 4.7s	remaining: 3.7s
# 560:	learn: 0.0809951	total: 4.71s	remaining: 3.69s
# 561:	learn: 0.0809701	total: 4.72s	remaining: 3.68s
# 562:	learn: 0.0809458	total: 4.73s	remaining: 3.67s
# 563:	learn: 0.0809325	total: 4.74s	remaining: 3.66s
# 564:	learn: 0.0809065	total: 4.74s	remaining: 3.65s
# 565:	learn: 0.0808908	total: 4.75s	remaining: 3.64s
# 566:	learn: 0.0808720	total: 4.76s	remaining: 3.63s
# 567:	learn: 0.0808483	total: 4.77s	remaining: 3.63s
# 568:	learn: 0.0808365	total: 4.78s	remaining: 3.62s
# 569:	learn: 0.0808197	total: 4.79s	remaining: 3.61s
# 570:	learn: 0.0807985	total: 4.8s	remaining: 3.6s
# 571:	learn: 0.0807798	total: 4.81s	remaining: 3.6s
# 572:	learn: 0.0807526	total: 4.81s	remaining: 3.59s
# 573:	learn: 0.0807384	total: 4.82s	remaining: 3.58s
# 574:	learn: 0.0807296	total: 4.83s	remaining: 3.57s
# 575:	learn: 0.0807098	total: 4.84s	remaining: 3.56s
# 576:	learn: 0.0806957	total: 4.84s	remaining: 3.55s
# 577:	learn: 0.0806783	total: 4.86s	remaining: 3.55s
# 578:	learn: 0.0806544	total: 4.87s	remaining: 3.54s
# 579:	learn: 0.0806416	total: 4.88s	remaining: 3.53s
# 580:	learn: 0.0806270	total: 4.88s	remaining: 3.52s
# 581:	learn: 0.0806070	total: 4.89s	remaining: 3.51s
# 582:	learn: 0.0805939	total: 4.9s	remaining: 3.5s
# 583:	learn: 0.0805713	total: 4.91s	remaining: 3.49s
# 584:	learn: 0.0805540	total: 4.91s	remaining: 3.49s
# 585:	learn: 0.0805343	total: 4.92s	remaining: 3.48s
# 586:	learn: 0.0805235	total: 4.93s	remaining: 3.47s
# 587:	learn: 0.0805034	total: 4.94s	remaining: 3.46s
# 588:	learn: 0.0804798	total: 4.94s	remaining: 3.45s
# 589:	learn: 0.0804603	total: 4.95s	remaining: 3.44s
# 590:	learn: 0.0804451	total: 4.96s	remaining: 3.43s
# 591:	learn: 0.0804317	total: 4.97s	remaining: 3.42s
# 592:	learn: 0.0804197	total: 4.97s	remaining: 3.41s
# 593:	learn: 0.0804024	total: 4.98s	remaining: 3.4s
# 594:	learn: 0.0803786	total: 4.99s	remaining: 3.4s
# 595:	learn: 0.0803652	total: 5s	remaining: 3.39s
# 596:	learn: 0.0803417	total: 5.01s	remaining: 3.38s
# 597:	learn: 0.0803348	total: 5.02s	remaining: 3.37s
# 598:	learn: 0.0803250	total: 5.03s	remaining: 3.37s
# 599:	learn: 0.0803176	total: 5.03s	remaining: 3.36s
# 600:	learn: 0.0802995	total: 5.04s	remaining: 3.35s
# 601:	learn: 0.0802828	total: 5.05s	remaining: 3.34s
# 602:	learn: 0.0802691	total: 5.06s	remaining: 3.33s
# 603:	learn: 0.0802498	total: 5.07s	remaining: 3.32s
# 604:	learn: 0.0802280	total: 5.07s	remaining: 3.31s
# 605:	learn: 0.0802133	total: 5.08s	remaining: 3.3s
# 606:	learn: 0.0802003	total: 5.09s	remaining: 3.29s
# 607:	learn: 0.0801806	total: 5.1s	remaining: 3.29s
# 608:	learn: 0.0801582	total: 5.11s	remaining: 3.28s
# 609:	learn: 0.0801413	total: 5.11s	remaining: 3.27s
# 610:	learn: 0.0801221	total: 5.12s	remaining: 3.26s
# 611:	learn: 0.0800801	total: 5.13s	remaining: 3.25s
# 612:	learn: 0.0800631	total: 5.14s	remaining: 3.24s
# 613:	learn: 0.0800447	total: 5.15s	remaining: 3.24s
# 614:	learn: 0.0800287	total: 5.16s	remaining: 3.23s
# 615:	learn: 0.0800160	total: 5.16s	remaining: 3.22s
# 616:	learn: 0.0799960	total: 5.17s	remaining: 3.21s
# 617:	learn: 0.0799824	total: 5.18s	remaining: 3.2s
# 618:	learn: 0.0799687	total: 5.18s	remaining: 3.19s
# 619:	learn: 0.0799502	total: 5.2s	remaining: 3.18s
# 620:	learn: 0.0799324	total: 5.21s	remaining: 3.18s
# 621:	learn: 0.0799159	total: 5.22s	remaining: 3.17s
# 622:	learn: 0.0798975	total: 5.23s	remaining: 3.16s
# 623:	learn: 0.0798809	total: 5.24s	remaining: 3.16s
# 624:	learn: 0.0798598	total: 5.25s	remaining: 3.15s
# 625:	learn: 0.0798483	total: 5.25s	remaining: 3.14s
# 626:	learn: 0.0798266	total: 5.26s	remaining: 3.13s
# 627:	learn: 0.0798115	total: 5.27s	remaining: 3.12s
# 628:	learn: 0.0797945	total: 5.28s	remaining: 3.11s
# 629:	learn: 0.0797844	total: 5.29s	remaining: 3.1s
# 630:	learn: 0.0797731	total: 5.29s	remaining: 3.1s
# 631:	learn: 0.0797577	total: 5.3s	remaining: 3.09s
# 632:	learn: 0.0797431	total: 5.31s	remaining: 3.08s
# 633:	learn: 0.0797237	total: 5.32s	remaining: 3.07s
# 634:	learn: 0.0796965	total: 5.33s	remaining: 3.06s
# 635:	learn: 0.0796793	total: 5.33s	remaining: 3.05s
# 636:	learn: 0.0796670	total: 5.34s	remaining: 3.04s
# 637:	learn: 0.0796482	total: 5.35s	remaining: 3.03s
# 638:	learn: 0.0796329	total: 5.36s	remaining: 3.03s
# 639:	learn: 0.0795992	total: 5.37s	remaining: 3.02s
# 640:	learn: 0.0795856	total: 5.37s	remaining: 3.01s
# 641:	learn: 0.0795579	total: 5.38s	remaining: 3s
# 642:	learn: 0.0795400	total: 5.39s	remaining: 2.99s
# 643:	learn: 0.0795232	total: 5.4s	remaining: 2.98s
# 644:	learn: 0.0795089	total: 5.41s	remaining: 2.98s
# 645:	learn: 0.0794897	total: 5.42s	remaining: 2.97s
# 646:	learn: 0.0794743	total: 5.43s	remaining: 2.96s
# 647:	learn: 0.0794505	total: 5.44s	remaining: 2.95s
# 648:	learn: 0.0794318	total: 5.45s	remaining: 2.94s
# 649:	learn: 0.0794135	total: 5.45s	remaining: 2.94s
# 650:	learn: 0.0794006	total: 5.46s	remaining: 2.93s
# 651:	learn: 0.0793913	total: 5.47s	remaining: 2.92s
# 652:	learn: 0.0793706	total: 5.48s	remaining: 2.91s
# 653:	learn: 0.0793527	total: 5.49s	remaining: 2.9s
# 654:	learn: 0.0793373	total: 5.5s	remaining: 2.89s
# 655:	learn: 0.0793212	total: 5.5s	remaining: 2.88s
# 656:	learn: 0.0793021	total: 5.51s	remaining: 2.88s
# 657:	learn: 0.0792875	total: 5.52s	remaining: 2.87s
# 658:	learn: 0.0792664	total: 5.53s	remaining: 2.86s
# 659:	learn: 0.0792494	total: 5.54s	remaining: 2.85s
# 660:	learn: 0.0792330	total: 5.54s	remaining: 2.84s
# 661:	learn: 0.0792247	total: 5.55s	remaining: 2.83s
# 662:	learn: 0.0792129	total: 5.56s	remaining: 2.83s
# 663:	learn: 0.0791957	total: 5.57s	remaining: 2.82s
# 664:	learn: 0.0791737	total: 5.58s	remaining: 2.81s
# 665:	learn: 0.0791554	total: 5.59s	remaining: 2.8s
# 666:	learn: 0.0791415	total: 5.59s	remaining: 2.79s
# 667:	learn: 0.0791142	total: 5.6s	remaining: 2.78s
# 668:	learn: 0.0791023	total: 5.62s	remaining: 2.78s
# 669:	learn: 0.0790918	total: 5.62s	remaining: 2.77s
# 670:	learn: 0.0790845	total: 5.63s	remaining: 2.76s
# 671:	learn: 0.0790612	total: 5.64s	remaining: 2.75s
# 672:	learn: 0.0790329	total: 5.65s	remaining: 2.75s
# 673:	learn: 0.0790168	total: 5.66s	remaining: 2.74s
# 674:	learn: 0.0789964	total: 5.67s	remaining: 2.73s
# 675:	learn: 0.0789739	total: 5.67s	remaining: 2.72s
# 676:	learn: 0.0789609	total: 5.68s	remaining: 2.71s
# 677:	learn: 0.0789502	total: 5.69s	remaining: 2.7s
# 678:	learn: 0.0789386	total: 5.7s	remaining: 2.69s
# 679:	learn: 0.0789222	total: 5.71s	remaining: 2.69s
# 680:	learn: 0.0789121	total: 5.72s	remaining: 2.68s
# 681:	learn: 0.0788994	total: 5.72s	remaining: 2.67s
# 682:	learn: 0.0788921	total: 5.73s	remaining: 2.66s
# 683:	learn: 0.0788726	total: 5.74s	remaining: 2.65s
# 684:	learn: 0.0788585	total: 5.75s	remaining: 2.64s
# 685:	learn: 0.0788423	total: 5.75s	remaining: 2.63s
# 686:	learn: 0.0788238	total: 5.76s	remaining: 2.63s
# 687:	learn: 0.0788163	total: 5.77s	remaining: 2.62s
# 688:	learn: 0.0788027	total: 5.78s	remaining: 2.61s
# 689:	learn: 0.0787849	total: 5.79s	remaining: 2.6s
# 690:	learn: 0.0787688	total: 5.79s	remaining: 2.59s
# 691:	learn: 0.0787601	total: 5.8s	remaining: 2.58s
# 692:	learn: 0.0787439	total: 5.81s	remaining: 2.58s
# 693:	learn: 0.0787238	total: 5.82s	remaining: 2.57s
# 694:	learn: 0.0787106	total: 5.84s	remaining: 2.56s
# 695:	learn: 0.0786921	total: 5.85s	remaining: 2.55s
# 696:	learn: 0.0786826	total: 5.86s	remaining: 2.54s
# 697:	learn: 0.0786697	total: 5.86s	remaining: 2.54s
# 698:	learn: 0.0786557	total: 5.87s	remaining: 2.53s
# 699:	learn: 0.0786400	total: 5.88s	remaining: 2.52s
# 700:	learn: 0.0786182	total: 5.89s	remaining: 2.51s
# 701:	learn: 0.0786059	total: 5.89s	remaining: 2.5s
# 702:	learn: 0.0785964	total: 5.9s	remaining: 2.49s
# 703:	learn: 0.0785746	total: 5.91s	remaining: 2.48s
# 704:	learn: 0.0785625	total: 5.92s	remaining: 2.48s
# 705:	learn: 0.0785503	total: 5.92s	remaining: 2.47s
# 706:	learn: 0.0785368	total: 5.93s	remaining: 2.46s
# 707:	learn: 0.0785270	total: 5.94s	remaining: 2.45s
# 708:	learn: 0.0785080	total: 5.95s	remaining: 2.44s
# 709:	learn: 0.0785005	total: 5.96s	remaining: 2.43s
# 710:	learn: 0.0784911	total: 5.96s	remaining: 2.42s
# 711:	learn: 0.0784770	total: 5.97s	remaining: 2.42s
# 712:	learn: 0.0784582	total: 5.98s	remaining: 2.41s
# 713:	learn: 0.0784484	total: 5.99s	remaining: 2.4s
# 714:	learn: 0.0784388	total: 5.99s	remaining: 2.39s
# 715:	learn: 0.0784247	total: 6s	remaining: 2.38s
# 716:	learn: 0.0784086	total: 6.01s	remaining: 2.37s
# 717:	learn: 0.0783958	total: 6.02s	remaining: 2.37s
# 718:	learn: 0.0783845	total: 6.03s	remaining: 2.36s
# 719:	learn: 0.0783687	total: 6.04s	remaining: 2.35s
# 720:	learn: 0.0783545	total: 6.04s	remaining: 2.34s
# 721:	learn: 0.0783386	total: 6.05s	remaining: 2.33s
# 722:	learn: 0.0783248	total: 6.06s	remaining: 2.32s
# 723:	learn: 0.0783062	total: 6.07s	remaining: 2.31s
# 724:	learn: 0.0782907	total: 6.08s	remaining: 2.3s
# 725:	learn: 0.0782792	total: 6.08s	remaining: 2.3s
# 726:	learn: 0.0782659	total: 6.09s	remaining: 2.29s
# 727:	learn: 0.0782452	total: 6.1s	remaining: 2.28s
# 728:	learn: 0.0782293	total: 6.11s	remaining: 2.27s
# 729:	learn: 0.0782149	total: 6.12s	remaining: 2.26s
# 730:	learn: 0.0782037	total: 6.12s	remaining: 2.25s
# 731:	learn: 0.0781815	total: 6.13s	remaining: 2.24s
# 732:	learn: 0.0781664	total: 6.14s	remaining: 2.23s
# 733:	learn: 0.0781478	total: 6.14s	remaining: 2.23s
# 734:	learn: 0.0781305	total: 6.15s	remaining: 2.22s
# 735:	learn: 0.0781165	total: 6.16s	remaining: 2.21s
# 736:	learn: 0.0781015	total: 6.17s	remaining: 2.2s
# 737:	learn: 0.0780867	total: 6.18s	remaining: 2.19s
# 738:	learn: 0.0780714	total: 6.18s	remaining: 2.18s
# 739:	learn: 0.0780542	total: 6.19s	remaining: 2.17s
# 740:	learn: 0.0780425	total: 6.2s	remaining: 2.17s
# 741:	learn: 0.0780352	total: 6.21s	remaining: 2.16s
# 742:	learn: 0.0780180	total: 6.22s	remaining: 2.15s
# 743:	learn: 0.0780106	total: 6.23s	remaining: 2.14s
# 744:	learn: 0.0779979	total: 6.24s	remaining: 2.13s
# 745:	learn: 0.0779787	total: 6.25s	remaining: 2.13s
# 746:	learn: 0.0779651	total: 6.25s	remaining: 2.12s
# 747:	learn: 0.0779510	total: 6.26s	remaining: 2.11s
# 748:	learn: 0.0779315	total: 6.27s	remaining: 2.1s
# 749:	learn: 0.0779161	total: 6.28s	remaining: 2.09s
# 750:	learn: 0.0778984	total: 6.29s	remaining: 2.08s
# 751:	learn: 0.0778776	total: 6.29s	remaining: 2.08s
# 752:	learn: 0.0778617	total: 6.3s	remaining: 2.07s
# 753:	learn: 0.0778386	total: 6.31s	remaining: 2.06s
# 754:	learn: 0.0778293	total: 6.32s	remaining: 2.05s
# 755:	learn: 0.0778144	total: 6.33s	remaining: 2.04s
# 756:	learn: 0.0777928	total: 6.34s	remaining: 2.03s
# 757:	learn: 0.0777807	total: 6.34s	remaining: 2.02s
# 758:	learn: 0.0777583	total: 6.35s	remaining: 2.02s
# 759:	learn: 0.0777432	total: 6.36s	remaining: 2.01s
# 760:	learn: 0.0777287	total: 6.37s	remaining: 2s
# 761:	learn: 0.0777139	total: 6.38s	remaining: 1.99s
# 762:	learn: 0.0777040	total: 6.38s	remaining: 1.98s
# 763:	learn: 0.0776911	total: 6.39s	remaining: 1.98s
# 764:	learn: 0.0776801	total: 6.4s	remaining: 1.97s
# 765:	learn: 0.0776621	total: 6.41s	remaining: 1.96s
# 766:	learn: 0.0776441	total: 6.42s	remaining: 1.95s
# 767:	learn: 0.0776196	total: 6.43s	remaining: 1.94s
# 768:	learn: 0.0776101	total: 6.44s	remaining: 1.93s
# 769:	learn: 0.0775987	total: 6.45s	remaining: 1.93s
# 770:	learn: 0.0775899	total: 6.46s	remaining: 1.92s
# 771:	learn: 0.0775799	total: 6.47s	remaining: 1.91s
# 772:	learn: 0.0775715	total: 6.48s	remaining: 1.9s
# 773:	learn: 0.0775560	total: 6.49s	remaining: 1.89s
# 774:	learn: 0.0775398	total: 6.5s	remaining: 1.89s
# 775:	learn: 0.0775256	total: 6.51s	remaining: 1.88s
# 776:	learn: 0.0775178	total: 6.51s	remaining: 1.87s
# 777:	learn: 0.0775038	total: 6.52s	remaining: 1.86s
# 778:	learn: 0.0774893	total: 6.53s	remaining: 1.85s
# 779:	learn: 0.0774706	total: 6.54s	remaining: 1.84s
# 780:	learn: 0.0774542	total: 6.56s	remaining: 1.84s
# 781:	learn: 0.0774411	total: 6.57s	remaining: 1.83s
# 782:	learn: 0.0774281	total: 6.57s	remaining: 1.82s
# 783:	learn: 0.0774189	total: 6.58s	remaining: 1.81s
# 784:	learn: 0.0774086	total: 6.59s	remaining: 1.8s
# 785:	learn: 0.0773942	total: 6.6s	remaining: 1.8s
# 786:	learn: 0.0773698	total: 6.61s	remaining: 1.79s
# 787:	learn: 0.0773557	total: 6.61s	remaining: 1.78s
# 788:	learn: 0.0773428	total: 6.63s	remaining: 1.77s
# 789:	learn: 0.0773289	total: 6.63s	remaining: 1.76s
# 790:	learn: 0.0773216	total: 6.64s	remaining: 1.75s
# 791:	learn: 0.0772922	total: 6.65s	remaining: 1.75s
# 792:	learn: 0.0772747	total: 6.66s	remaining: 1.74s
# 793:	learn: 0.0772607	total: 6.67s	remaining: 1.73s
# 794:	learn: 0.0772486	total: 6.67s	remaining: 1.72s
# 795:	learn: 0.0772394	total: 6.68s	remaining: 1.71s
# 796:	learn: 0.0772256	total: 6.69s	remaining: 1.7s
# 797:	learn: 0.0772185	total: 6.7s	remaining: 1.7s
# 798:	learn: 0.0771984	total: 6.71s	remaining: 1.69s
# 799:	learn: 0.0771859	total: 6.71s	remaining: 1.68s
# 800:	learn: 0.0771675	total: 6.72s	remaining: 1.67s
# 801:	learn: 0.0771490	total: 6.73s	remaining: 1.66s
# 802:	learn: 0.0771418	total: 6.74s	remaining: 1.65s
# 803:	learn: 0.0771289	total: 6.74s	remaining: 1.64s
# 804:	learn: 0.0771121	total: 6.75s	remaining: 1.64s
# 805:	learn: 0.0770927	total: 6.76s	remaining: 1.63s
# 806:	learn: 0.0770753	total: 6.77s	remaining: 1.62s
# 807:	learn: 0.0770634	total: 6.78s	remaining: 1.61s
# 808:	learn: 0.0770460	total: 6.78s	remaining: 1.6s
# 809:	learn: 0.0770351	total: 6.79s	remaining: 1.59s
# 810:	learn: 0.0770292	total: 6.8s	remaining: 1.58s
# 811:	learn: 0.0770113	total: 6.81s	remaining: 1.58s
# 812:	learn: 0.0769948	total: 6.82s	remaining: 1.57s
# 813:	learn: 0.0769794	total: 6.83s	remaining: 1.56s
# 814:	learn: 0.0769661	total: 6.84s	remaining: 1.55s
# 815:	learn: 0.0769579	total: 6.85s	remaining: 1.54s
# 816:	learn: 0.0769499	total: 6.86s	remaining: 1.54s
# 817:	learn: 0.0769383	total: 6.87s	remaining: 1.53s
# 818:	learn: 0.0769271	total: 6.87s	remaining: 1.52s
# 819:	learn: 0.0769193	total: 6.88s	remaining: 1.51s
# 820:	learn: 0.0769009	total: 6.89s	remaining: 1.5s
# 821:	learn: 0.0768819	total: 6.9s	remaining: 1.49s
# 822:	learn: 0.0768724	total: 6.91s	remaining: 1.49s
# 823:	learn: 0.0768509	total: 6.91s	remaining: 1.48s
# 824:	learn: 0.0768386	total: 6.92s	remaining: 1.47s
# 825:	learn: 0.0768268	total: 6.93s	remaining: 1.46s
# 826:	learn: 0.0768097	total: 6.94s	remaining: 1.45s
# 827:	learn: 0.0767952	total: 6.95s	remaining: 1.44s
# 828:	learn: 0.0767821	total: 6.95s	remaining: 1.43s
# 829:	learn: 0.0767742	total: 6.96s	remaining: 1.43s
# 830:	learn: 0.0767534	total: 6.97s	remaining: 1.42s
# 831:	learn: 0.0767404	total: 6.98s	remaining: 1.41s
# 832:	learn: 0.0767279	total: 6.99s	remaining: 1.4s
# 833:	learn: 0.0767150	total: 7s	remaining: 1.39s
# 834:	learn: 0.0766984	total: 7s	remaining: 1.38s
# 835:	learn: 0.0766746	total: 7.02s	remaining: 1.38s
# 836:	learn: 0.0766580	total: 7.04s	remaining: 1.37s
# 837:	learn: 0.0766331	total: 7.04s	remaining: 1.36s
# 838:	learn: 0.0766177	total: 7.05s	remaining: 1.35s
# 839:	learn: 0.0766019	total: 7.06s	remaining: 1.34s
# 840:	learn: 0.0765937	total: 7.07s	remaining: 1.34s
# 841:	learn: 0.0765860	total: 7.08s	remaining: 1.33s
# 842:	learn: 0.0765727	total: 7.08s	remaining: 1.32s
# 843:	learn: 0.0765628	total: 7.09s	remaining: 1.31s
# 844:	learn: 0.0765522	total: 7.1s	remaining: 1.3s
# 845:	learn: 0.0765420	total: 7.11s	remaining: 1.29s
# 846:	learn: 0.0765297	total: 7.11s	remaining: 1.28s
# 847:	learn: 0.0765216	total: 7.12s	remaining: 1.28s
# 848:	learn: 0.0765104	total: 7.13s	remaining: 1.27s
# 849:	learn: 0.0764888	total: 7.14s	remaining: 1.26s
# 850:	learn: 0.0764723	total: 7.14s	remaining: 1.25s
# 851:	learn: 0.0764625	total: 7.15s	remaining: 1.24s
# 852:	learn: 0.0764411	total: 7.16s	remaining: 1.23s
# 853:	learn: 0.0764243	total: 7.17s	remaining: 1.23s
# 854:	learn: 0.0764089	total: 7.17s	remaining: 1.22s
# 855:	learn: 0.0763968	total: 7.18s	remaining: 1.21s
# 856:	learn: 0.0763896	total: 7.19s	remaining: 1.2s
# 857:	learn: 0.0763771	total: 7.2s	remaining: 1.19s
# 858:	learn: 0.0763534	total: 7.21s	remaining: 1.18s
# 859:	learn: 0.0763360	total: 7.21s	remaining: 1.17s
# 860:	learn: 0.0763250	total: 7.22s	remaining: 1.17s
# 861:	learn: 0.0763102	total: 7.23s	remaining: 1.16s
# 862:	learn: 0.0762938	total: 7.24s	remaining: 1.15s
# 863:	learn: 0.0762867	total: 7.25s	remaining: 1.14s
# 864:	learn: 0.0762785	total: 7.26s	remaining: 1.13s
# 865:	learn: 0.0762699	total: 7.26s	remaining: 1.12s
# 866:	learn: 0.0762582	total: 7.27s	remaining: 1.11s
# 867:	learn: 0.0762436	total: 7.28s	remaining: 1.11s
# 868:	learn: 0.0762312	total: 7.29s	remaining: 1.1s
# 869:	learn: 0.0762195	total: 7.29s	remaining: 1.09s
# 870:	learn: 0.0762016	total: 7.3s	remaining: 1.08s
# 871:	learn: 0.0761841	total: 7.31s	remaining: 1.07s
# 872:	learn: 0.0761741	total: 7.32s	remaining: 1.06s
# 873:	learn: 0.0761682	total: 7.33s	remaining: 1.06s
# 874:	learn: 0.0761565	total: 7.34s	remaining: 1.05s
# 875:	learn: 0.0761438	total: 7.34s	remaining: 1.04s
# 876:	learn: 0.0761346	total: 7.35s	remaining: 1.03s
# 877:	learn: 0.0761237	total: 7.36s	remaining: 1.02s
# 878:	learn: 0.0761139	total: 7.37s	remaining: 1.01s
# 879:	learn: 0.0761026	total: 7.38s	remaining: 1.01s
# 880:	learn: 0.0760917	total: 7.39s	remaining: 998ms
# 881:	learn: 0.0760689	total: 7.39s	remaining: 989ms
# 882:	learn: 0.0760572	total: 7.4s	remaining: 981ms
# 883:	learn: 0.0760482	total: 7.41s	remaining: 973ms
# 884:	learn: 0.0760372	total: 7.42s	remaining: 964ms
# 885:	learn: 0.0760238	total: 7.43s	remaining: 956ms
# 886:	learn: 0.0760047	total: 7.44s	remaining: 948ms
# 887:	learn: 0.0759915	total: 7.45s	remaining: 940ms
# 888:	learn: 0.0759715	total: 7.46s	remaining: 931ms
# 889:	learn: 0.0759615	total: 7.47s	remaining: 923ms
# 890:	learn: 0.0759436	total: 7.48s	remaining: 915ms
# 891:	learn: 0.0759231	total: 7.49s	remaining: 906ms
# 892:	learn: 0.0759072	total: 7.49s	remaining: 898ms
# 893:	learn: 0.0758941	total: 7.5s	remaining: 890ms
# 894:	learn: 0.0758856	total: 7.51s	remaining: 881ms
# 895:	learn: 0.0758771	total: 7.52s	remaining: 873ms
# 896:	learn: 0.0758587	total: 7.53s	remaining: 864ms
# 897:	learn: 0.0758514	total: 7.53s	remaining: 856ms
# 898:	learn: 0.0758331	total: 7.54s	remaining: 847ms
# 899:	learn: 0.0758217	total: 7.55s	remaining: 839ms
# 900:	learn: 0.0758025	total: 7.56s	remaining: 831ms
# 901:	learn: 0.0757969	total: 7.57s	remaining: 822ms
# 902:	learn: 0.0757881	total: 7.58s	remaining: 814ms
# 903:	learn: 0.0757769	total: 7.58s	remaining: 805ms
# 904:	learn: 0.0757625	total: 7.59s	remaining: 797ms
# 905:	learn: 0.0757525	total: 7.6s	remaining: 788ms
# 906:	learn: 0.0757400	total: 7.61s	remaining: 780ms
# 907:	learn: 0.0757300	total: 7.62s	remaining: 772ms
# 908:	learn: 0.0757155	total: 7.62s	remaining: 763ms
# 909:	learn: 0.0757089	total: 7.64s	remaining: 755ms
# 910:	learn: 0.0756989	total: 7.64s	remaining: 747ms
# 911:	learn: 0.0756867	total: 7.65s	remaining: 738ms
# 912:	learn: 0.0756747	total: 7.66s	remaining: 730ms
# 913:	learn: 0.0756617	total: 7.67s	remaining: 722ms
# 914:	learn: 0.0756507	total: 7.68s	remaining: 713ms
# 915:	learn: 0.0756349	total: 7.69s	remaining: 705ms
# 916:	learn: 0.0756238	total: 7.7s	remaining: 697ms
# 917:	learn: 0.0756142	total: 7.71s	remaining: 689ms
# 918:	learn: 0.0756064	total: 7.72s	remaining: 680ms
# 919:	learn: 0.0755816	total: 7.72s	remaining: 672ms
# 920:	learn: 0.0755688	total: 7.73s	remaining: 663ms
# 921:	learn: 0.0755530	total: 7.74s	remaining: 655ms
# 922:	learn: 0.0755409	total: 7.75s	remaining: 647ms
# 923:	learn: 0.0755265	total: 7.76s	remaining: 638ms
# 924:	learn: 0.0755117	total: 7.77s	remaining: 630ms
# 925:	learn: 0.0755004	total: 7.78s	remaining: 622ms
# 926:	learn: 0.0754881	total: 7.79s	remaining: 614ms
# 927:	learn: 0.0754695	total: 7.8s	remaining: 605ms
# 928:	learn: 0.0754520	total: 7.81s	remaining: 597ms
# 929:	learn: 0.0754435	total: 7.82s	remaining: 589ms
# 930:	learn: 0.0754341	total: 7.83s	remaining: 580ms
# 931:	learn: 0.0754288	total: 7.84s	remaining: 572ms
# 932:	learn: 0.0754161	total: 7.85s	remaining: 563ms
# 933:	learn: 0.0754083	total: 7.85s	remaining: 555ms
# 934:	learn: 0.0754004	total: 7.86s	remaining: 547ms
# 935:	learn: 0.0753836	total: 7.87s	remaining: 538ms
# 936:	learn: 0.0753723	total: 7.88s	remaining: 530ms
# 937:	learn: 0.0753625	total: 7.88s	remaining: 521ms
# 938:	learn: 0.0753485	total: 7.89s	remaining: 513ms
# 939:	learn: 0.0753383	total: 7.9s	remaining: 504ms
# 940:	learn: 0.0753320	total: 7.91s	remaining: 496ms
# 941:	learn: 0.0753202	total: 7.91s	remaining: 487ms
# 942:	learn: 0.0753044	total: 7.92s	remaining: 479ms
# 943:	learn: 0.0752910	total: 7.93s	remaining: 470ms
# 944:	learn: 0.0752774	total: 7.94s	remaining: 462ms
# 945:	learn: 0.0752661	total: 7.94s	remaining: 454ms
# 946:	learn: 0.0752525	total: 7.95s	remaining: 445ms
# 947:	learn: 0.0752423	total: 7.96s	remaining: 437ms
# 948:	learn: 0.0752309	total: 7.97s	remaining: 428ms
# 949:	learn: 0.0752152	total: 7.97s	remaining: 420ms
# 950:	learn: 0.0752065	total: 7.98s	remaining: 411ms
# 951:	learn: 0.0751942	total: 7.99s	remaining: 403ms
# 952:	learn: 0.0751786	total: 8s	remaining: 394ms
# 953:	learn: 0.0751704	total: 8.01s	remaining: 386ms
# 954:	learn: 0.0751570	total: 8.01s	remaining: 378ms
# 955:	learn: 0.0751478	total: 8.02s	remaining: 369ms
# 956:	learn: 0.0751225	total: 8.03s	remaining: 361ms
# 957:	learn: 0.0751170	total: 8.05s	remaining: 353ms
# 958:	learn: 0.0751097	total: 8.05s	remaining: 344ms
# 959:	learn: 0.0750996	total: 8.06s	remaining: 336ms
# 960:	learn: 0.0750939	total: 8.07s	remaining: 327ms
# 961:	learn: 0.0750793	total: 8.08s	remaining: 319ms
# 962:	learn: 0.0750674	total: 8.08s	remaining: 311ms
# 963:	learn: 0.0750566	total: 8.09s	remaining: 302ms
# 964:	learn: 0.0750488	total: 8.1s	remaining: 294ms
# 965:	learn: 0.0750395	total: 8.11s	remaining: 285ms
# 966:	learn: 0.0750289	total: 8.12s	remaining: 277ms
# 967:	learn: 0.0750162	total: 8.12s	remaining: 269ms
# 968:	learn: 0.0750037	total: 8.13s	remaining: 260ms
# 969:	learn: 0.0749946	total: 8.14s	remaining: 252ms
# 970:	learn: 0.0749790	total: 8.15s	remaining: 243ms
# 971:	learn: 0.0749698	total: 8.15s	remaining: 235ms
# 972:	learn: 0.0749621	total: 8.16s	remaining: 227ms
# 973:	learn: 0.0749557	total: 8.17s	remaining: 218ms
# 974:	learn: 0.0749490	total: 8.18s	remaining: 210ms
# 975:	learn: 0.0749390	total: 8.19s	remaining: 201ms
# 976:	learn: 0.0749267	total: 8.2s	remaining: 193ms
# 977:	learn: 0.0749189	total: 8.2s	remaining: 185ms
# 978:	learn: 0.0749064	total: 8.21s	remaining: 176ms
# 979:	learn: 0.0748975	total: 8.22s	remaining: 168ms
# 980:	learn: 0.0748884	total: 8.23s	remaining: 159ms
# 981:	learn: 0.0748764	total: 8.23s	remaining: 151ms
# 982:	learn: 0.0748652	total: 8.24s	remaining: 143ms
# 983:	learn: 0.0748528	total: 8.26s	remaining: 134ms
# 984:	learn: 0.0748427	total: 8.26s	remaining: 126ms
# 985:	learn: 0.0748324	total: 8.27s	remaining: 117ms
# 986:	learn: 0.0748191	total: 8.28s	remaining: 109ms
# 987:	learn: 0.0748076	total: 8.29s	remaining: 101ms
# 988:	learn: 0.0747924	total: 8.29s	remaining: 92.3ms
# 989:	learn: 0.0747856	total: 8.3s	remaining: 83.9ms
# 990:	learn: 0.0747776	total: 8.31s	remaining: 75.5ms
# 991:	learn: 0.0747685	total: 8.32s	remaining: 67.1ms
# 992:	learn: 0.0747530	total: 8.33s	remaining: 58.7ms
# 993:	learn: 0.0747390	total: 8.34s	remaining: 50.3ms
# 994:	learn: 0.0747278	total: 8.35s	remaining: 41.9ms
# 995:	learn: 0.0747175	total: 8.35s	remaining: 33.5ms
# 996:	learn: 0.0746974	total: 8.36s	remaining: 25.2ms
# 997:	learn: 0.0746842	total: 8.37s	remaining: 16.8ms
# 998:	learn: 0.0746706	total: 8.38s	remaining: 8.39ms
# 999:	learn: 0.0746591	total: 8.39s	remaining: 0us
# 0.7637764695031494

# %%
#from sklearn.model_selection import train_test_split
#from xgboost import XGBRegressor
#x_train,x_val,y_train,y_val=train_test_split(train_prp,y,test_size=0.1,random_state=42)

# %%
#using the mean_squared error as metric
from sklearn.metrics import mean_squared_error
print("the mean square error for country {} is {}".format(a,mean_squared_error(y_val,model_3.predict(x_val))))
# Out:
# the mean square error for country Guinea is 0.008128704740007606

# %%
#from sklearn.ensemble import RandomForestRegressor
#model=RandomForestRegressor()
# creating our randomforest model
#model.fit(x_train,y_train)#fitting our randomforest model
#model.score(x_val,y_val)

# %%
#model2
#model_2=XGBRegressor()
#model_2.fit(x_train,y_train)#fitting our randomforest model
#model_2.score(x_val,y_val)

# %%
#from lightgbm import LGBMRegressor
#model_4=LGBMRegressor()
#model_4.fit(x_train,y_train)#fitting our randomforest model
#model_4.score(x_val,y_val)

# %%
#creating our submission file
submit["Target"]=model_3.predict(test_prp)

# %%
submit.head()
# Out:
#             ID    Target
# 0  ID_AAcismbB  0.112599
# 1  ID_AAeBMsji  0.180794
# 2  ID_AAjFMjzy  0.629592
# 3  ID_AAmMOEEC  0.393371
# 4  ID_ABguzDxp  0.208487

# %%
submit.to_csv("baseline.csv",index=False)

# %%
#model = CatBoostClassifier(iterations=1000,
#                           loss_function=best_param['loss_function'],
#                           depth=best_param['depth'],
#                           l2_leaf_reg=best_param['l2_leaf_reg'],
#                           eval_metric='Accuracy',
#                           leaf_estimation_iterations=10,
#                           use_best_model=True,
#                           logging_level='Silent',
#                          random_seed=42
#                          )

# %%
g=train[train.country=="Guinea"]

# %%
#data summary for the country Guinea
g.describe()
# Out:
#               year  ghsl_water_surface  ...  built_year  abnormal_light
# count   593.000000          593.000000  ...  593.000000      593.000000
# mean   2005.576728            0.067622  ...    0.494098        0.001686
# std       6.505034            0.177058  ...    0.500387        0.041065
# min    1999.000000            0.000000  ...    0.000000        0.000000
# 25%    1999.000000            0.000000  ...    0.000000        0.000000
# 50%    2012.000000            0.000000  ...    0.000000        0.000000
# 75%    2012.000000            0.000018  ...    1.000000        0.000000
# max    2012.000000            0.907501  ...    1.000000        1.000000
#
# [8 rows x 22 columns]
